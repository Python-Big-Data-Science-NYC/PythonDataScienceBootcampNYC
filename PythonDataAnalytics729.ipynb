# %%
import pandas as pd

# %%
df = pd.read_csv('dummydata - Sheet1.csv')
df
# Out:
#    SiteName TypeofSite      Location ApprovedorNot  NumerofClinicians
# 0      BLEU         PC        Queens           Yes                  2
# 1       XXX         BH      Brooklyn            No                  2
# 2       YYY         PC     Manhattan           Yes                  3
# 3       ABC         BH  Staten Islan            No                  4
# 4       GGG         PC        Queens           Yes                  2
# 5       HHH         BH      Brooklyn            No                  2
# 6       ASD         PC     Manhattan           Yes                  3
# 7       SDF         BH  Staten Islan            No                  4
# 8       DSA         PC        Queens           Yes                  2
# 9       FDF         BH      Brooklyn            No                  3
# 10      FDF         PC     Manhattan           Yes                  2

# %%
df.columns
# Out:
# Index(['SiteName', 'TypeofSite', 'Location', 'ApprovedorNot',
#        'NumerofClinicians'],
#       dtype='object')

# %%
df[['SiteName','NumerofClinicians']]
# Out:
#    SiteName  NumerofClinicians
# 0      BLEU                  2
# 1       XXX                  2
# 2       YYY                  3
# 3       ABC                  4
# 4       GGG                  2
# 5       HHH                  2
# 6       ASD                  3
# 7       SDF                  4
# 8       DSA                  2
# 9       FDF                  3
# 10      FDF                  2

# %%
dfqueens = df[df['Location']=='Queens']

# %%
dfqueens['NumerofClinicians'].sum()
# Out:
# 6

# %%
df[(df['Location']=='Manhattan') & (df['NumerofClinicians']==3) ]
# Out:
#   SiteName TypeofSite   Location ApprovedorNot  NumerofClinicians
# 2      YYY         PC  Manhattan           Yes                  3
# 6      ASD         PC  Manhattan           Yes                  3

# %%
df[(df['Location']=='Manhattan') ]
# Out:
#    SiteName TypeofSite   Location ApprovedorNot  NumerofClinicians
# 2       YYY         PC  Manhattan           Yes                  3
# 6       ASD         PC  Manhattan           Yes                  3
# 10      FDF         PC  Manhattan           Yes                  2

# %%
df[df['NumerofClinicians']>3]
# Out:
#   SiteName TypeofSite      Location ApprovedorNot  NumerofClinicians
# 3      ABC         BH  Staten Islan            No                  4
# 7      SDF         BH  Staten Islan            No                  4

# %%
# grouped by Location Sum of number of clinians 

df.groupby(['TypeofSite'])['NumerofClinicians'].sum()
# Out:
# TypeofSite
# BH    15
# PC    14
# Name: NumerofClinicians, dtype: int64

# %%
dflang = pd.read_csv('dummydata - Sheet2.csv')

# %%
dflang
# Out:
#         City     Spanish     English       Hindi        Urdu     Russian  \
# 0     Queens   51.941267  556.500464  521.787095  114.729365  389.188901
# 1  Manhattan  943.659338  411.736398  659.910559  416.308176   81.302376
# 2   Brooklyn  666.636001  139.860327  611.070876  490.861691  714.698432
#
#        French
# 0  860.509595
# 1  400.905088
# 2  938.367326

# %%
df
# Out:
#    SiteName TypeofSite      Location ApprovedorNot  NumerofClinicians
# 0      BLEU         PC        Queens           Yes                  2
# 1       XXX         BH      Brooklyn            No                  2
# 2       YYY         PC     Manhattan           Yes                  3
# 3       ABC         BH  Staten Islan            No                  4
# 4       GGG         PC        Queens           Yes                  2
# 5       HHH         BH      Brooklyn            No                  2
# 6       ASD         PC     Manhattan           Yes                  3
# 7       SDF         BH  Staten Islan            No                  4
# 8       DSA         PC        Queens           Yes                  2
# 9       FDF         BH      Brooklyn            No                  3
# 10      FDF         PC     Manhattan           Yes                  2

# %%
df.merge(dflang, left_on='Location', right_on='City', how='outer')
# Out:
#    SiteName TypeofSite      Location ApprovedorNot  NumerofClinicians  \
# 0      BLEU         PC        Queens           Yes                  2
# 1       GGG         PC        Queens           Yes                  2
# 2       DSA         PC        Queens           Yes                  2
# 3       XXX         BH      Brooklyn            No                  2
# 4       HHH         BH      Brooklyn            No                  2
# 5       FDF         BH      Brooklyn            No                  3
# 6       YYY         PC     Manhattan           Yes                  3
# 7       ASD         PC     Manhattan           Yes                  3
# 8       FDF         PC     Manhattan           Yes                  2
# 9       ABC         BH  Staten Islan            No                  4
# 10      SDF         BH  Staten Islan            No                  4
#
#          City     Spanish     English       Hindi        Urdu     Russian  \
# 0      Queens   51.941267  556.500464  521.787095  114.729365  389.188901
# 1      Queens   51.941267  556.500464  521.787095  114.729365  389.188901
# 2      Queens   51.941267  556.500464  521.787095  114.729365  389.188901
# 3    Brooklyn  666.636001  139.860327  611.070876  490.861691  714.698432
# 4    Brooklyn  666.636001  139.860327  611.070876  490.861691  714.698432
# 5    Brooklyn  666.636001  139.860327  611.070876  490.861691  714.698432
# 6   Manhattan  943.659338  411.736398  659.910559  416.308176   81.302376
# 7   Manhattan  943.659338  411.736398  659.910559  416.308176   81.302376
# 8   Manhattan  943.659338  411.736398  659.910559  416.308176   81.302376
# 9         NaN         NaN         NaN         NaN         NaN         NaN
# 10        NaN         NaN         NaN         NaN         NaN         NaN
#
#         French
# 0   860.509595
# 1   860.509595
# 2   860.509595
# 3   938.367326
# 4   938.367326
# 5   938.367326
# 6   400.905088
# 7   400.905088
# 8   400.905088
# 9          NaN
# 10         NaN

# %%
pd.read_csv('http://blockchainainyc.com/wp-content/uploads/2018/06/avgsal-2.csv')
# Out:
#   City  Avg Salary
# 0    M       15000
# 1    B       17000
# 2    Q       10000

# %%
df = pd.DataFrame({'key': ['foo', 'bar', 'baz'],
                   'A': [1, 2, 3],
                   'B': [4, 5, 6],
                   'C': [7, 8, 9]})
df
# Out:
#    A  B  C  key
# 0  1  4  7  foo
# 1  2  5  8  bar
# 2  3  6  9  baz

# %%
melted = pd.melt(df, ['key'])
melted
# Out:
#    key variable  value
# 0  foo        A      1
# 1  bar        A      2
# 2  baz        A      3
# 3  foo        B      4
# 4  bar        B      5
# 5  baz        B      6
# 6  foo        C      7
# 7  bar        C      8
# 8  baz        C      9

# %%
reshaped = melted.pivot('key', 'variable', 'value')
reshaped
# Out:
# variable  A  B  C
# key
# bar       2  5  8
# baz       3  6  9
# foo       1  4  7

# %%
df = pd.read_csv('dummydata - Sheet1.csv')

# %%
df2 = df[['ApprovedorNot','Location', 'NumerofClinicians' ]]
df2
# Out:
#    ApprovedorNot      Location  NumerofClinicians
# 0            Yes        Queens                  2
# 1             No      Brooklyn                  2
# 2            Yes     Manhattan                  3
# 3             No  Staten Islan                  4
# 4            Yes        Queens                  2
# 5             No      Brooklyn                  2
# 6            Yes     Manhattan                  3
# 7             No  Staten Islan                  4
# 8            Yes        Queens                  2
# 9             No      Brooklyn                  3
# 10           Yes     Manhattan                  2

# %%
df2.drop_duplicates(keep=False, inplace=True)
reshaped = df2.pivot('ApprovedorNot', 'Location', 'NumerofClinicians')
reshaped
# Out:
# /home/nbuser/anaconda3_501/lib/python3.6/site-packages/ipykernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-49-0f4c8f000c58> in <module>()
#       1 df2.drop_duplicates(inplace=True)
# ----> 2 reshaped = df2.pivot('ApprovedorNot', 'Location', 'NumerofClinicians')
#       3 reshaped
#
# ~/anaconda3_501/lib/python3.6/site-packages/pandas/core/frame.py in pivot(self, index, columns, values)
#    3851         """
#    3852         from pandas.core.reshape.reshape import pivot
# -> 3853         return pivot(self, index=index, columns=columns, values=values)
#    3854
#    3855     def stack(self, level=-1, dropna=True):
#
# ~/anaconda3_501/lib/python3.6/site-packages/pandas/core/reshape/reshape.py in pivot(self, index, columns, values)
#     376         indexed = Series(self[values].values,
#     377                          index=MultiIndex.from_arrays([index, self[columns]]))
# --> 378         return indexed.unstack(columns)
#     379
#     380
#
# ~/anaconda3_501/lib/python3.6/site-packages/pandas/core/series.py in unstack(self, level, fill_value)
#    2026         """
#    2027         from pandas.core.reshape.reshape import unstack
# -> 2028         return unstack(self, level, fill_value)
#    2029
#    2030     # ----------------------------------------------------------------------
#
# ~/anaconda3_501/lib/python3.6/site-packages/pandas/core/reshape/reshape.py in unstack(obj, level, fill_value)
#     456     else:
#     457         unstacker = _Unstacker(obj.values, obj.index, level=level,
# --> 458                                fill_value=fill_value)
#     459         return unstacker.get_result()
#     460
#
# ~/anaconda3_501/lib/python3.6/site-packages/pandas/core/reshape/reshape.py in __init__(self, values, index, level, value_columns, fill_value)
#     108
#     109         self._make_sorted_values_labels()
# --> 110         self._make_selectors()
#     111
#     112     def _make_sorted_values_labels(self):
#
# ~/anaconda3_501/lib/python3.6/site-packages/pandas/core/reshape/reshape.py in _make_selectors(self)
#     146
#     147         if mask.sum() < len(self.index):
# --> 148             raise ValueError('Index contains duplicate entries, '
#     149                              'cannot reshape')
#     150
#
# ValueError: Index contains duplicate entries, cannot reshape

# %%
# Out:
# /home/nbuser/anaconda3_501/lib/python3.6/site-packages/ipykernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
